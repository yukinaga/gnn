# %% [markdown]
# <a href="https://colab.research.google.com/github/yukinaga/gnn/blob/main/section_1/02_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 演習
# Tensor同士の演算を練習しましょう。

# %% [markdown]
# ## Tensor同士の演算
# 以下のコードにおけるTensor、`a`と`b`の間で演算を行い、結果を表示しましょう。
# `a`は2次元のTensorで`b`は1次元のTensorなので、ブロードキャストが必要です。

# %%
import torch

a = torch.tensor([[11, 12, 13],
                  [14, 15, 16]])
b = torch.tensor([1, 2, 3]) 

print("--- 和 ---")


print("--- 差 ---")


print("--- 積 ---")


print("--- 商（小数） ---")


print("--- 商（整数） ---")


print("--- 余り ---")

# %% [markdown]
# ### 〇解答例
# 以下は解答例です。

# %%
import torch

a = torch.tensor([[11, 12, 13],
                  [14, 15, 16]])
b = torch.tensor([1, 2, 3]) 

print("--- 和 ---")
print(a + b)

print("--- 差 ---")
print(a - b)

print("--- 積 ---")
print(a * b)

print("--- 商（小数） ---")
print(a / b)

print("--- 商（整数） ---")
print(a // b)

print("--- 余り ---")
print(a % b)
